# %%
# !pip install requests bs4
# Out:
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting bs4
#   Using cached bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.4.4-cp314-cp314-macosx_10_13_universal2.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.6.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting beautifulsoup4 (from bs4)
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->bs4)
#   Using cached soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4->bs4)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp314-cp314-macosx_10_13_universal2.whl (207 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.6.0-py3-none-any.whl (131 kB)
# Using cached bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached soupsieve-2.8-py3-none-any.whl (36 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: urllib3, typing-extensions, soupsieve, idna, charset_normalizer, certifi, requests, beautifulsoup4, bs4
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [bs4]4/9 [charset_normalizer]
# Successfully installed beautifulsoup4-4.14.3 bs4-0.0.2 certifi-2025.11.12 charset_normalizer-3.4.4 idna-3.11 requests-2.32.5 soupsieve-2.8 typing-extensions-4.15.0 urllib3-2.6.0

# %%
import os
import re
import json
import requests
import zipfile
import shutil
import subprocess
import threading
from concurrent.futures import ThreadPoolExecutor, as_completed
from bs4 import BeautifulSoup
from datetime import datetime
from pathlib import Path

# ---------------- CONFIG ----------------
HTML_FILE = 'memories_history.html'
DOWNLOAD_FOLDER = 'snapchat_memories'
LOG_FILE = 'downloaded_files.json'
ERROR_LOG_FILE = 'download_errors.json'
MAX_WORKERS = 5  # Anzahl paralleler Downloads
TEST_MODE = False  # Auf True setzen für Test-Modus
TEST_FILES_PER_THREAD = 5  # Anzahl Dateien pro Thread im Test-Modus
USE_EXIFTOOL = True  # Auf False setzen, wenn exiftool nicht verfügbar ist
# ----------------------------------------

os.makedirs(DOWNLOAD_FOLDER, exist_ok=True)

# Thread-Lock für JSON-Schreibzugriff
json_lock = threading.Lock()
error_lock = threading.Lock()

# Bereits heruntergeladene Dateien laden (jetzt mit unique_id als Key)
if os.path.exists(LOG_FILE):
    with open(LOG_FILE, 'r', encoding='utf-8') as f:
        downloaded_files = json.load(f)
else:
    downloaded_files = {}

# Fehlerhafte Downloads laden
if os.path.exists(ERROR_LOG_FILE):
    with open(ERROR_LOG_FILE, 'r', encoding='utf-8') as f:
        error_log = json.load(f)
else:
    error_log = {}

# HTML einlesen und parsen
with open(HTML_FILE, 'r', encoding='utf-8') as f:
    html_content = f.read()

soup = BeautifulSoup(html_content, 'html.parser')

# Alle downloadMemories Links und zugehörige Daten extrahieren
pattern = r"downloadMemories\('(.+?)',\s*this,\s*(true|false)\)"
matches = re.findall(pattern, html_content)

# Aufnahmedatum aus der Tabelle extrahieren
def extract_dates_from_table():
    """Extrahiert alle Aufnahmedaten aus der Tabelle"""
    dates = []
    table = soup.select_one('body > div.rightpanel > table > tbody')
    if table:
        rows = table.find_all('tr')
        for row in rows:
            cells = row.find_all('td')
            if cells:
                date_text = cells[0].get_text(strip=True)
                dates.append(date_text)
    return dates

dates = extract_dates_from_table()
print(f"{len(matches)} Dateien gefunden, {len(dates)} Datum-Einträge gefunden.")

# Prüfe ob exiftool verfügbar ist
def check_exiftool():
    """Prüft, ob exiftool installiert ist"""
    try:
        subprocess.run(['exiftool', '-ver'], capture_output=True, check=True)
        return True
    except (subprocess.CalledProcessError, FileNotFoundError):
        return False

exiftool_available = check_exiftool() if USE_EXIFTOOL else False
if USE_EXIFTOOL and not exiftool_available:
    print("WARNUNG: exiftool nicht gefunden. Metadaten werden nicht geschrieben.")
    print("Installation: https://exiftool.org/")
elif exiftool_available:
    print("exiftool gefunden - Metadaten werden in Dateien geschrieben.")

def extract_unique_id_from_url(url):
    """Extrahiert die eindeutige ID (mid) aus der URL"""
    mid_match = re.search(r'mid=([a-zA-Z0-9\-]+)', url)
    if mid_match:
        return mid_match.group(1)
    else:
        # Fallback: Hash der gesamten URL
        import hashlib
        return hashlib.md5(url.encode()).hexdigest()

def get_file_extension_from_url(url):
    """Ermittelt die Dateierweiterung aus der URL oder dem Content-Type"""
    url_path = url.split('?')[0]
    if '.' in url_path.split('/')[-1]:
        ext = os.path.splitext(url_path)[1]
        if ext in ['.mp4', '.jpg', '.jpeg', '.png', '.zip']:
            return ext
    return None

def build_filename(unique_id, date_str=None, content_type=None, url=None):
    """Erstellt einen Dateinamen basierend auf unique_id, Datum und Content-Type"""
    base_name = unique_id
    
    # Datum hinzufügen, falls vorhanden
    if date_str:
        try:
            date_cleaned = date_str.strip()
            for fmt in ['%Y-%m-%d %H:%M:%S %Z', '%Y-%m-%d %H:%M:%S', '%Y-%m-%d']:
                try:
                    dt = datetime.strptime(date_cleaned.replace('UTC', '').strip(), fmt.replace(' %Z', ''))
                    date_prefix = dt.strftime('%Y%m%d_%H%M%S')
                    base_name = f"{date_prefix}_{base_name}"
                    break
                except:
                    continue
        except:
            pass
    
    # Erweiterung bestimmen
    ext = get_file_extension_from_url(url) if url else None
    if not ext and content_type:
        if 'video' in content_type:
            ext = '.mp4'
        elif 'image/jpeg' in content_type or 'image/jpg' in content_type:
            ext = '.jpg'
        elif 'image/png' in content_type:
            ext = '.png'
        elif 'zip' in content_type:
            ext = '.zip'
    
    if not ext:
        ext = '.mp4'  # Fallback
    
    filename = base_name + ext
    filepath = os.path.join(DOWNLOAD_FOLDER, filename)
    
    return filepath, filename

def extract_and_cleanup_zip(zip_path):
    """Entpackt ZIP-Datei und löscht die ZIP"""
    try:
        extract_folder = os.path.splitext(zip_path)[0]
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(extract_folder)
        os.remove(zip_path)
        print(f"[ZIP] Entpackt und ZIP gelöscht: {os.path.basename(zip_path)}")
        return extract_folder
    except Exception as e:
        print(f"[ZIP ERROR] Fehler beim Entpacken von {os.path.basename(zip_path)}: {e}")
        return None

def parse_date_string(date_str):
    """Parst Datum-String in datetime-Objekt"""
    if not date_str:
        return None
    
    try:
        date_cleaned = date_str.strip()
        for fmt in ['%Y-%m-%d %H:%M:%S %Z', '%Y-%m-%d %H:%M:%S', '%Y-%m-%d', 
                    '%d.%m.%Y %H:%M:%S', '%d.%m.%Y']:
            try:
                dt = datetime.strptime(date_cleaned.replace('UTC', '').strip(), fmt.replace(' %Z', ''))
                return dt
            except:
                continue
    except:
        pass
    return None

def write_metadata_to_file(filepath, date_str, silent=False):
    """Schreibt Aufnahmedatum in die Metadaten der Datei"""
    if not exiftool_available or not date_str:
        return False
    
    dt = parse_date_string(date_str)
    if not dt:
        return False
    
    try:
        exif_date = dt.strftime('%Y:%m:%d %H:%M:%S')
        
        file_ext = os.path.splitext(filepath)[1].lower()
        filename = os.path.basename(filepath)
        
        if '-overlay' in filename.lower() or 'thumbnail' in filename.lower():
            if not silent:
                print(f"[SKIP] Überspringe Metadaten für: {filename}")
            try:
                timestamp = dt.timestamp()
                os.utime(filepath, (timestamp, timestamp))
            except:
                pass
            return False
        
        if file_ext in ['.jpg', '.jpeg', '.png']:
            result = subprocess.run([
                'exiftool',
                '-overwrite_original',
                '-q',
                f'-DateTimeOriginal={exif_date}',
                f'-CreateDate={exif_date}',
                f'-ModifyDate={exif_date}',
                filepath
            ], capture_output=True)
            
            if result.returncode != 0 and not silent:
                return False
            
        elif file_ext in ['.mp4', '.mov', '.avi']:
            result = subprocess.run([
                'exiftool',
                '-overwrite_original',
                '-q',
                f'-CreateDate={exif_date}',
                f'-MediaCreateDate={exif_date}',
                f'-TrackCreateDate={exif_date}',
                f'-ModifyDate={exif_date}',
                filepath
            ], capture_output=True)
            
            if result.returncode != 0 and not silent:
                return False
        
        timestamp = dt.timestamp()
        os.utime(filepath, (timestamp, timestamp))
        
        return True
        
    except Exception as e:
        if not silent:
            print(f"[METADATA] Konnte Metadaten nicht schreiben für: {os.path.basename(filepath)}")
        return False

def process_files_in_folder(folder_path, date_str):
    """Schreibt Metadaten für alle Dateien in einem Ordner (für entpackte ZIPs)"""
    if not os.path.isdir(folder_path):
        return
    
    success_count = 0
    skip_count = 0
    
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            if file_path.lower().endswith(('.jpg', '.jpeg', '.png', '.mp4', '.mov', '.avi')):
                result = write_metadata_to_file(file_path, date_str, silent=True)
                if result:
                    success_count += 1
                else:
                    skip_count += 1
    
    if success_count > 0 or skip_count > 0:
        print(f"[ZIP-INHALT] {success_count} Dateien mit Metadaten versehen, {skip_count} übersprungen.")

def log_error(unique_id, url, date_str, error_message, index):
    """Speichert fehlgeschlagene Downloads in separater JSON-Datei"""
    with error_lock:
        error_log[unique_id] = {
            'url': url,
            'date': date_str,
            'error': str(error_message),
            'index': index,
            'timestamp': datetime.now().isoformat()
        }
        try:
            with open(ERROR_LOG_FILE, 'w', encoding='utf-8') as f:
                json.dump(error_log, f, indent=2, ensure_ascii=False)
        except Exception as e:
            print(f"[ERROR LOG] Fehler beim Speichern der Fehlerliste: {e}")

def download_file(url, is_get_request, date_str=None, index=None):
    """Lädt eine Datei herunter mit korrekter Dateierweiterung"""
    unique_id = extract_unique_id_from_url(url)
    
    # Prüfe ob bereits heruntergeladen (anhand unique_id)
    if unique_id in downloaded_files:
        print(f"[SKIP] {unique_id} bereits heruntergeladen.")
        return unique_id, 'skipped'
    
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                         'AppleWebKit/537.36 (KHTML, like Gecko) '
                         'Chrome/119.0.0.0 Safari/537.36'
        }
        
        # Anfrage um Content-Type zu ermitteln
        if is_get_request:
            r = requests.get(url, headers=headers, stream=True, allow_redirects=True, timeout=60)
        else:
            parts = url.split('?')
            post_url = parts[0]
            post_data = parts[1] if len(parts) > 1 else ''
            r = requests.post(post_url, headers=headers, data=post_data,
                            stream=True, allow_redirects=True, timeout=60)
        
        r.raise_for_status()
        
        content_type = r.headers.get('Content-Type', '')
        
        # Dateinamen generieren (ohne Suffix-Logik)
        filepath, filename = build_filename(unique_id, date_str, content_type, url)
        
        # Datei herunterladen
        with open(filepath, 'wb') as f:
            for chunk in r.iter_content(1024*1024):
                f.write(chunk)
        
        # Metadaten schreiben
        metadata_written = write_metadata_to_file(filepath, date_str)
        
        # Wenn ZIP, entpacken und Metadaten für Inhalte schreiben
        if filepath.endswith('.zip'):
            extract_folder = extract_and_cleanup_zip(filepath)
            if extract_folder:
                process_files_in_folder(extract_folder, date_str)
        
        # Speichere mit unique_id als Key
        downloaded_files[unique_id] = {
            'filename': filename,
            'url': url,
            'date': date_str,
            'content_type': content_type,
            'metadata_written': metadata_written,
            'timestamp': datetime.now().isoformat()
        }
        
        print(f"[OK] {filename} heruntergeladen{' (Metadaten geschrieben)' if metadata_written else ''}.")
        return unique_id, 'downloaded'
        
    except Exception as e:
        print(f"[ERROR] Download fehlgeschlagen für {unique_id} (Index {index}): {e}")
        log_error(unique_id, url, date_str, e, index)
        return unique_id, 'error'

def save_progress():
    """Speichert den aktuellen Fortschritt in die JSON-Datei (Thread-safe)"""
    with json_lock:
        try:
            with open(LOG_FILE, 'w', encoding='utf-8') as f:
                json.dump(downloaded_files, f, indent=2, ensure_ascii=False)
            return True
        except Exception as e:
            print(f"[JSON ERROR] Fehler beim Speichern: {e}")
            return False

# Download-Liste vorbereiten
download_tasks = []
for i, (url, is_get) in enumerate(matches):
    date_str = dates[i] if i < len(dates) else None
    download_tasks.append((url, is_get == 'true', date_str, i))

# Test-Modus: Begrenze Anzahl der Downloads
if TEST_MODE:
    total_test_files = MAX_WORKERS * TEST_FILES_PER_THREAD
    download_tasks = download_tasks[:total_test_files]
    print(f"\n*** TEST-MODUS AKTIV: Lade nur {len(download_tasks)} Dateien ({TEST_FILES_PER_THREAD} pro Thread) ***\n")

# Statistiken
print(f"\nBereits heruntergeladen: {len(downloaded_files)} Dateien")
print(f"Fehlerhafte Downloads: {len(error_log)} Dateien")
print(f"Zu bearbeiten: {len(download_tasks)} Dateien\n")

# Parallel Downloads
completed_count = 0
downloaded_count = 0
skipped_count = 0
error_count = 0
total_count = len(download_tasks)

with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    futures = [executor.submit(download_file, url, is_get, date, idx) 
               for url, is_get, date, idx in download_tasks]
    
    for future in as_completed(futures):
        unique_id, status = future.result()
        completed_count += 1
        
        if status == 'downloaded':
            downloaded_count += 1
            save_progress()
        elif status == 'skipped':
            skipped_count += 1
        elif status == 'error':
            error_count += 1
            
        # Fortschrittsanzeige
        if completed_count % 10 == 0 or completed_count == total_count:
            print(f"\n[FORTSCHRITT] {completed_count}/{total_count} Dateien bearbeitet "
                  f"(Heruntergeladen: {downloaded_count}, Übersprungen: {skipped_count}, Fehler: {error_count})\n")

# Finale Speicherung
save_progress()

print("\n=== Download-Zusammenfassung ===")
print(f"Gesamt bearbeitet: {len(download_tasks)} Dateien")
print(f"Neu heruntergeladen: {downloaded_count} Dateien")
print(f"Übersprungen (bereits vorhanden): {skipped_count} Dateien")
print(f"Fehler: {error_count} Dateien")
print(f"Gesamt erfolgreich: {len(downloaded_files)} Dateien")
if error_count > 0:
# [SKIP] 83514406-AD91-4196-938C-55D95048883E bereits heruntergeladen.
# [SKIP] 548247C4-A562-4D65-B2B1-384DE685ED68 bereits heruntergeladen.
# [SKIP] B38A3C1E-7562-4A44-8562-FEE21DE6E529 bereits heruntergeladen.
# [SKIP] 13BA094F-7740-45D9-B111-A9A5D1866FB9 bereits heruntergeladen.
# [SKIP] E1826402-3CAE-4CB6-9C39-72F1149E7F7D bereits heruntergeladen.
# [SKIP] C6FA3C6A-6A54-47BE-9088-67B68AE7FEA9 bereits heruntergeladen.
# [SKIP] A3ACC22F-D413-4D65-B43F-18AC9EE77960 bereits heruntergeladen.
# [SKIP] 7B4D193A-F41D-43AC-936B-2BC1297FA7CA bereits heruntergeladen.
# [SKIP] 191C0DF2-169E-42D4-9DEB-5CA13D5B368C bereits heruntergeladen.
# ...
#
#
# [FORTSCHRITT] 7610/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7610, Fehler: 0)
#
#
# [FORTSCHRITT] 7620/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7620, Fehler: 0)
#
#
# [FORTSCHRITT] 7630/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7630, Fehler: 0)
#
#
# [FORTSCHRITT] 7640/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7640, Fehler: 0)
#
#
# [FORTSCHRITT] 7650/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7650, Fehler: 0)
#
#
# [FORTSCHRITT] 7660/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7660, Fehler: 0)
#
#
# [FORTSCHRITT] 7670/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7670, Fehler: 0)
#
#
# [FORTSCHRITT] 7680/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7680, Fehler: 0)
#
#
# [FORTSCHRITT] 7690/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7690, Fehler: 0)
#
#
# [FORTSCHRITT] 7700/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7700, Fehler: 0)
#
#
# [FORTSCHRITT] 7710/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7710, Fehler: 0)
#
#
# [FORTSCHRITT] 7720/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7720, Fehler: 0)
#
#
# [FORTSCHRITT] 7730/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7730, Fehler: 0)
#
#
# [FORTSCHRITT] 7740/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7740, Fehler: 0)
#
#
# [FORTSCHRITT] 7750/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7750, Fehler: 0)
#
#
# [FORTSCHRITT] 7760/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7760, Fehler: 0)
#
#
# [FORTSCHRITT] 7770/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7770, Fehler: 0)
#
#
# [FORTSCHRITT] 7780/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7780, Fehler: 0)
#
#
# [FORTSCHRITT] 7790/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7790, Fehler: 0)
#
#
# [FORTSCHRITT] 7800/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7800, Fehler: 0)
#
#
# [FORTSCHRITT] 7810/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7810, Fehler: 0)
#
#
# [FORTSCHRITT] 7820/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7820, Fehler: 0)
#
#
# [FORTSCHRITT] 7830/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7830, Fehler: 0)
#
#
# [FORTSCHRITT] 7840/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7840, Fehler: 0)
#
#
# [FORTSCHRITT] 7850/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7850, Fehler: 0)
#
#
# [FORTSCHRITT] 7860/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7860, Fehler: 0)
#
#
# [FORTSCHRITT] 7870/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7870, Fehler: 0)
#
#
# [FORTSCHRITT] 7880/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7880, Fehler: 0)
#
#
# [FORTSCHRITT] 7890/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7890, Fehler: 0)
#
#
# [FORTSCHRITT] 7900/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7900, Fehler: 0)
#
#
# [FORTSCHRITT] 7910/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7910, Fehler: 0)
#
#
# [FORTSCHRITT] 7920/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7920, Fehler: 0)
#
#
# [FORTSCHRITT] 7930/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7930, Fehler: 0)
#
#
# [FORTSCHRITT] 7940/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7940, Fehler: 0)
#
#
# [FORTSCHRITT] 7950/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7950, Fehler: 0)
#
#
# [FORTSCHRITT] 7960/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7960, Fehler: 0)
#
#
# [FORTSCHRITT] 7970/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7970, Fehler: 0)
#
#
# [FORTSCHRITT] 7980/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7980, Fehler: 0)
#
#
# [FORTSCHRITT] 7990/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 7990, Fehler: 0)
#
#
# [FORTSCHRITT] 8000/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8000, Fehler: 0)
#
#
# [FORTSCHRITT] 8010/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8010, Fehler: 0)
#
#
# [FORTSCHRITT] 8020/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8020, Fehler: 0)
#
#
# [FORTSCHRITT] 8030/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8030, Fehler: 0)
#
#
# [FORTSCHRITT] 8040/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8040, Fehler: 0)
#
#
# [FORTSCHRITT] 8050/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8050, Fehler: 0)
#
#
# [FORTSCHRITT] 8060/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8060, Fehler: 0)
#
#
# [FORTSCHRITT] 8070/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8070, Fehler: 0)
#
#
# [FORTSCHRITT] 8080/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8080, Fehler: 0)
#
#
# [FORTSCHRITT] 8090/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8090, Fehler: 0)
#
#
# [FORTSCHRITT] 8100/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8100, Fehler: 0)
#
#
# [FORTSCHRITT] 8110/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8110, Fehler: 0)
#
#
# [FORTSCHRITT] 8120/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8120, Fehler: 0)
#
#
# [FORTSCHRITT] 8130/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8130, Fehler: 0)
#
#
# [FORTSCHRITT] 8140/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8140, Fehler: 0)
#
#
# [FORTSCHRITT] 8150/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8150, Fehler: 0)
#
#
# [FORTSCHRITT] 8160/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8160, Fehler: 0)
#
#
# [FORTSCHRITT] 8170/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8170, Fehler: 0)
#
#
# [FORTSCHRITT] 8180/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8180, Fehler: 0)
#
#
# [FORTSCHRITT] 8190/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8190, Fehler: 0)
#
#
# [FORTSCHRITT] 8200/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8200, Fehler: 0)
#
#
# [FORTSCHRITT] 8210/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8210, Fehler: 0)
#
#
# [FORTSCHRITT] 8220/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8220, Fehler: 0)
#
#
# [FORTSCHRITT] 8230/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8230, Fehler: 0)
#
#
# [FORTSCHRITT] 8240/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8240, Fehler: 0)
#
#
# [FORTSCHRITT] 8250/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8250, Fehler: 0)
#
#
# [FORTSCHRITT] 8260/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8260, Fehler: 0)
#
#
# [FORTSCHRITT] 8270/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8270, Fehler: 0)
#
#
# [FORTSCHRITT] 8280/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8280, Fehler: 0)
#
#
# [FORTSCHRITT] 8290/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8290, Fehler: 0)
#
#
# [FORTSCHRITT] 8300/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8300, Fehler: 0)
#
#
# [FORTSCHRITT] 8310/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8310, Fehler: 0)
#
#
# [FORTSCHRITT] 8320/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8320, Fehler: 0)
#
#
# [FORTSCHRITT] 8330/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8330, Fehler: 0)
#
#
# [FORTSCHRITT] 8340/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8340, Fehler: 0)
#
#
# [FORTSCHRITT] 8350/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8350, Fehler: 0)
#
#
# [FORTSCHRITT] 8360/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8360, Fehler: 0)
#
#
# [FORTSCHRITT] 8370/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8370, Fehler: 0)
#
#
# [FORTSCHRITT] 8380/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8380, Fehler: 0)
#
#
# [FORTSCHRITT] 8390/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8390, Fehler: 0)
#
#
# [FORTSCHRITT] 8400/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8400, Fehler: 0)
#
#
# [FORTSCHRITT] 8410/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8410, Fehler: 0)
#
#
# [FORTSCHRITT] 8420/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8420, Fehler: 0)
#
#
# [FORTSCHRITT] 8430/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8430, Fehler: 0)
#
#
# [FORTSCHRITT] 8440/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8440, Fehler: 0)
#
#
# [FORTSCHRITT] 8450/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8450, Fehler: 0)
#
#
# [FORTSCHRITT] 8460/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8460, Fehler: 0)
#
#
# [FORTSCHRITT] 8470/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8470, Fehler: 0)
#
#
# [FORTSCHRITT] 8480/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8480, Fehler: 0)
#
#
# [FORTSCHRITT] 8490/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8490, Fehler: 0)
#
#
# [FORTSCHRITT] 8500/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8500, Fehler: 0)
#
#
# [FORTSCHRITT] 8510/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8510, Fehler: 0)
#
#
# [FORTSCHRITT] 8520/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8520, Fehler: 0)
#
#
# [FORTSCHRITT] 8530/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8530, Fehler: 0)
#
#
# [FORTSCHRITT] 8540/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8540, Fehler: 0)
#
#
# [FORTSCHRITT] 8550/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8550, Fehler: 0)
#
#
# [FORTSCHRITT] 8560/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8560, Fehler: 0)
#
#
# [FORTSCHRITT] 8570/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8570, Fehler: 0)
#
#
# [FORTSCHRITT] 8580/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8580, Fehler: 0)
#
#
# [FORTSCHRITT] 8590/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8590, Fehler: 0)
#
#
# [FORTSCHRITT] 8600/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8600, Fehler: 0)
#
#
# [FORTSCHRITT] 8610/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8610, Fehler: 0)
#
#
# [FORTSCHRITT] 8620/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8620, Fehler: 0)
#
#
# [FORTSCHRITT] 8630/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8630, Fehler: 0)
#
#
# [FORTSCHRITT] 8640/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8640, Fehler: 0)
#
#
# [FORTSCHRITT] 8650/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8650, Fehler: 0)
#
#
# [FORTSCHRITT] 8660/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8660, Fehler: 0)
#
#
# [FORTSCHRITT] 8670/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8670, Fehler: 0)
#
#
# [FORTSCHRITT] 8680/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8680, Fehler: 0)
#
#
# [FORTSCHRITT] 8690/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8690, Fehler: 0)
#
#
# [FORTSCHRITT] 8700/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8700, Fehler: 0)
#
#
# [FORTSCHRITT] 8710/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8710, Fehler: 0)
#
#
# [FORTSCHRITT] 8720/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8720, Fehler: 0)
#
#
# [FORTSCHRITT] 8730/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8730, Fehler: 0)
#
#
# [FORTSCHRITT] 8740/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8740, Fehler: 0)
#
#
# [FORTSCHRITT] 8750/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8750, Fehler: 0)
#
#
# [FORTSCHRITT] 8760/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8760, Fehler: 0)
#
#
# [FORTSCHRITT] 8770/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8770, Fehler: 0)
#
#
# [FORTSCHRITT] 8780/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8780, Fehler: 0)
#
#
# [FORTSCHRITT] 8790/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8790, Fehler: 0)
#
#
# [FORTSCHRITT] 8800/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8800, Fehler: 0)
#
#
# [FORTSCHRITT] 8810/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8810, Fehler: 0)
#
#
# [FORTSCHRITT] 8820/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8820, Fehler: 0)
#
#
# [FORTSCHRITT] 8830/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8830, Fehler: 0)
#
#
# [FORTSCHRITT] 8840/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8840, Fehler: 0)
#
#
# [FORTSCHRITT] 8850/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8850, Fehler: 0)
#
#
# [FORTSCHRITT] 8860/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8860, Fehler: 0)
#
#
# [FORTSCHRITT] 8870/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8870, Fehler: 0)
#
#
# [FORTSCHRITT] 8880/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8880, Fehler: 0)
#
#
# [FORTSCHRITT] 8890/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8890, Fehler: 0)
#
#
# [FORTSCHRITT] 8900/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8900, Fehler: 0)
#
#
# [FORTSCHRITT] 8910/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8910, Fehler: 0)
#
#
# [FORTSCHRITT] 8920/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8920, Fehler: 0)
#
#
# [FORTSCHRITT] 8930/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8930, Fehler: 0)
#
#
# [FORTSCHRITT] 8940/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8940, Fehler: 0)
#
#
# [FORTSCHRITT] 8950/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8950, Fehler: 0)
#
#
# [FORTSCHRITT] 8960/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8960, Fehler: 0)
#
#
# [FORTSCHRITT] 8970/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8970, Fehler: 0)
#
#
# [FORTSCHRITT] 8980/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8980, Fehler: 0)
#
#
# [FORTSCHRITT] 8990/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 8990, Fehler: 0)
#
#
# [FORTSCHRITT] 9000/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 9000, Fehler: 0)
#
#
# [FORTSCHRITT] 9010/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 9010, Fehler: 0)
#
#
# [FORTSCHRITT] 9020/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 9020, Fehler: 0)
#
#
# [FORTSCHRITT] 9030/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 9030, Fehler: 0)
#
#
# [FORTSCHRITT] 9040/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 9040, Fehler: 0)
#
#
# [FORTSCHRITT] 9050/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 9050, Fehler: 0)
#
#
# [FORTSCHRITT] 9060/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 9060, Fehler: 0)
#
#
# [FORTSCHRITT] 9070/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 9070, Fehler: 0)
#
#
# [FORTSCHRITT] 9080/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 9080, Fehler: 0)
#
#
# [FORTSCHRITT] 9090/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 9090, Fehler: 0)
#
#
# [FORTSCHRITT] 9100/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 9100, Fehler: 0)
#
#
# [FORTSCHRITT] 9110/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 9110, Fehler: 0)
#
#
# [FORTSCHRITT] 9120/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 9120, Fehler: 0)
#
# [ERROR] Download fehlgeschlagen für 701DFA87-9AFA-4263-9773-097C7BBBC59D (Index 6017): 500 Server Error: Internal Server Error for url: https://us-east1-aws.api.snapchat.com/dmd/mm?uid=b236919d-8a9e-4f67-b9c0-77c172d10b42&sid=701DFA87-9AFA-4263-9773-097C7BBBC59D&mid=701DFA87-9AFA-4263-9773-097C7BBBC59D&ts=1765132395135&sig=c57e6e47233fbcdd1e103bb461824957a83d5192a3b86969d6b1bb8fa421337e
# [ERROR] Download fehlgeschlagen für C2BB855F-8AA5-4EF0-85B8-9C94AA0A6716 (Index 6006): 500 Server Error: Internal Server Error for url: https://us-east1-aws.api.snapchat.com/dmd/mm?uid=b236919d-8a9e-4f67-b9c0-77c172d10b42&sid=C2BB855F-8AA5-4EF0-85B8-9C94AA0A6716&mid=C2BB855F-8AA5-4EF0-85B8-9C94AA0A6716&ts=1765132455511&sig=6680a9fb785923cb15e282e86fdbaffff4c0f2ead05145adb3124d9517d0e894
#
# [FORTSCHRITT] 9125/9125 Dateien bearbeitet (Heruntergeladen: 0, Übersprungen: 9123, Fehler: 2)
#
#
# === Download-Zusammenfassung ===
# Gesamt bearbeitet: 9125 Dateien
# Neu heruntergeladen: 0 Dateien
# Übersprungen (bereits vorhanden): 9123 Dateien
# Fehler: 2 Dateien
# Gesamt erfolgreich: 7485 Dateien
#
# Fehlerhafte Downloads wurden in 'download_errors.json' gespeichert.
#
# Alle Downloads bearbeitet.
